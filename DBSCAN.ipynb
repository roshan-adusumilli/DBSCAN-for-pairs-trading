# %%
# checkout what ; after code is
import matplotlib.pyplot as plt
import matplotlib.cm as cm

import numpy as np
import pandas as pd

from sklearn.cluster import KMeans, DBSCAN
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn import preprocessing

from statsmodels.tsa.stattools import coint

from scipy import stats

from quantopian.pipeline.data import morningstar
from quantopian.pipeline.filters.morningstar import Q500US, Q1500US, Q3000US
from quantopian.pipeline import Pipeline
from quantopian.research import run_pipeline

# %%
study_date = "2019-12-31"

# %%
universe = Q1500US()

# %%
pipe = Pipeline(columns = {'Market Cap': morningstar.valuation.market_cap.latest.quantiles(5),
        'Industry': morningstar.asset_classification.morningstar_industry_group_code.latest,
        'Financial Health': morningstar.asset_classification.financial_health_grade.latest}, 
        screen = universe)

# %%
res = run_pipeline(pipe, study_date, study_date)
res.index = res.index.droplevel(0)  # drop the single date from the multi-index
# Out:
# <b>Pipeline Execution Time:</b> 5.00 Seconds

# %%
print res.shape
res.head()
# Out:
# (1486, 3)
#                   Financial Health  Industry  Market Cap
# Equity(2 [ARNC])                 B     31070           4
# Equity(24 [AAPL])                A     31120           4
# Equity(53 [ABMD])                B     20650           4
# Equity(62 [ABT])                 A     20650           4
# Equity(67 [ADSK])                A     31110           4

# %%
# remove stocks in Industry "Conglomerates"
res = res[res['Industry']!=31055]
print res.shape
# Out:
# (1486, 3)

# %%
# remove stocks without a Financial Health grade
res = res[res['Financial Health']!= None]
print res.shape
# Out:
# (1484, 3)

# %%
# replace the categorical data with numerical scores per the docs
res['Financial Health'] = res['Financial Health'].astype('object')
health_dict = {u'A': 0.1,
               u'B': 0.3,
               u'C': 0.7,
               u'D': 0.9,
               u'F': 1.0}
res = res.replace({'Financial Health': health_dict})

# %%
res.describe()
# Out:
#        Financial Health      Industry   Market Cap
# count       1484.000000   1484.000000  1484.000000
# mean           0.447439  20811.819407     3.470350
# std            0.269562   9118.431082     0.617619
# min            0.100000  10110.000000     2.000000
# 25%            0.300000  10340.000000     3.000000
# 50%            0.300000  20630.000000     4.000000
# 75%            0.700000  31040.000000     4.000000
# max            1.000000  31130.000000     4.000000

# %%
pricing = get_pricing(
    symbols=res.index,
    fields='close_price',
    start_date=pd.Timestamp(study_date) - pd.DateOffset(months=24),
    end_date=pd.Timestamp(study_date)
)

# %%
pricing.shape
# Out:
# (503, 1484)

# %%
returns = pricing.pct_change()
returns[symbols(['AAPL'])].plot()

# %%
# we can only work with stocks that have the full return series
returns = returns.iloc[1:,:].dropna(axis=1)
print returns.shape
# Out:
# (502, 1358)

# %%
prin_components = 50 
pca = PCA(n_components=prin_components)
pca.fit(returns)
# Out:
# /venvs/py35/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# PCA(copy=True, n_components=50, whiten=False)

# %%
pca.components_.T.shape
# Out:
# (1358, 50)

# %%
X = np.hstack(
    (pca.components_.T,
     res['Market Cap'][returns.columns].values[:, np.newaxis],
     res['Financial Health'][returns.columns].values[:, np.newaxis])
)

print X.shape
# Out:
# (1358, 52)

# %%
X = preprocessing.StandardScaler().fit_transform(X)
print X.shape
# Out:
# (1358, 52)

# %%
clf = DBSCAN(eps=1.9, min_samples=3)
print clf

clf.fit(X)
labels = clf.labels_
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
print "\nClusters discovered: %d" % n_clusters_

clustered = clf.labels_
# Out:
# /venvs/py35/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# /venvs/py35/lib/python3.5/site-packages/sklearn/base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# DBSCAN(algorithm='auto', eps=1.9, leaf_size=30, metric='euclidean',
#     min_samples=3, p=None, random_state=None)
#
# Clusters discovered: 15

# %%
# the initial dimensionality of the search was, uses summation formula, trivia that it was discovered by
ticker_count = len(returns.columns)
print "Total pairs possible in universe: %d " % (ticker_count*(ticker_count-1)/2)
# Out:
# Total pairs possible in universe: 921403

# %%
clustered_series = pd.Series(index=returns.columns, data=clustered.flatten())
clustered_series_all = pd.Series(index=returns.columns, data=clustered.flatten())
clustered_series = clustered_series[clustered_series != -1]

# %%
CLUSTER_SIZE_LIMIT = 9999
counts = clustered_series.value_counts()
ticker_count_reduced = counts[(counts>1) & (counts<=CLUSTER_SIZE_LIMIT)]
print "Clusters formed: %d" % len(ticker_count_reduced)
print "Pairs to evaluate: %d" % (ticker_count_reduced*(ticker_count_reduced-1)).sum()
# Out:
# Clusters formed: 15
# Pairs to evaluate: 2256

# %%
X_tsne = TSNE(learning_rate=1000, perplexity=25, random_state=1337).fit_transform(X)

# %%
plt.figure(1, facecolor='white')
plt.clf()
plt.axis('off')

plt.scatter(
    X_tsne[(labels!=-1), 0],
    X_tsne[(labels!=-1), 1],
    s=100,
    alpha=0.85,
    c=labels[labels!=-1],
    cmap=cm.Paired
)

plt.scatter(
    X_tsne[(clustered_series_all==-1).values, 0],
    X_tsne[(clustered_series_all==-1).values, 1],
    s=100,
    alpha=0.05
)

plt.title('T-SNE of all Stocks with DBSCAN Clusters Noted');

# %%
plt.barh(
    range(len(clustered_series.value_counts())),
    clustered_series.value_counts()
)
plt.title('Cluster Member Counts')
plt.xlabel('Stocks in Cluster')
plt.ylabel('Cluster Number');

# %%
# get the number of stocks in each cluster
counts = clustered_series.value_counts()

# let's visualize some clusters
cluster_vis_list = list(counts[(counts<20) & (counts>1)].index)[::-1]

# plot a handful of the smallest clusters
for clust in cluster_vis_list[0:min(len(cluster_vis_list), 3)]:
    tickers = list(clustered_series[clustered_series==clust].index)
    means = np.log(pricing[tickers].mean())
    data = np.log(pricing[tickers]).sub(means)
    data.plot(title='Stock Time Series for Cluster %d' % clust)

# %%
which_cluster = clustered_series.loc[symbols('JPM')]
clustered_series[clustered_series == which_cluster]
# Out:
# Equity(700 [BAC])       3
# Equity(1335 [C])        3
# Equity(1620 [CMA])      3
# Equity(2855 [FITB])     3
# Equity(4221 [KEY])      3
# Equity(5117 [MTB])      3
# Equity(5479 [NTRS])     3
# Equity(6068 [PNC])      3
# Equity(8151 [WFC])      3
# Equity(8399 [ZION])     3
# Equity(17080 [MS])      3
# Equity(19787 [EWBC])    3
# Equity(20088 [GS])      3
# Equity(25006 [JPM])     3
# Equity(27421 [WAL])     3
# Equity(34913 [RF])      3
# Equity(47777 [CFG])     3
# dtype: int64

# %%
tickers = list(clustered_series[clustered_series==which_cluster].index)
means = np.log(pricing[tickers].mean())
data = np.log(pricing[tickers]).sub(means)
data.plot(legend=False, title="Stock Time Series for Cluster %d" % which_cluster);

# %%
def find_cointegrated_pairs(data, significance=0.05):
    # This function is from https://www.quantopian.com/lectures/introduction-to-pairs-trading
    n = data.shape[1]
    score_matrix = np.zeros((n, n))
    pvalue_matrix = np.ones((n, n))
    keys = data.keys()
    pairs = []
    for i in range(n):
        for j in range(i+1, n):
            S1 = data[keys[i]]
            S2 = data[keys[j]]
            result = coint(S1, S2)
            score = result[0]
            pvalue = result[1]
            score_matrix[i, j] = score
            pvalue_matrix[i, j] = pvalue
            if pvalue < significance:
                pairs.append((keys[i], keys[j]))
    return score_matrix, pvalue_matrix, pairs

# %%
cluster_dict = {}
for i, which_clust in enumerate(ticker_count_reduced.index):
    tickers = clustered_series[clustered_series == which_clust].index
    score_matrix, pvalue_matrix, pairs = find_cointegrated_pairs(
        pricing[tickers]
    )
    cluster_dict[which_clust] = {}
    cluster_dict[which_clust]['score_matrix'] = score_matrix
    cluster_dict[which_clust]['pvalue_matrix'] = pvalue_matrix
    cluster_dict[which_clust]['pairs'] = pairs

# %%
pairs = []
for clust in cluster_dict.keys():
    pairs.extend(cluster_dict[clust]['pairs'])

# %%
pairs
# Out:
# [(Equity(161 [AEP]), Equity(21964 [XEL])),
#  (Equity(161 [AEP]), Equity(36098 [AWK])),
#  (Equity(612 [ATO]), Equity(1665 [CMS])),
#  (Equity(2330 [DTE]), Equity(24783 [AEE])),
#  (Equity(2351 [DUK]), Equity(5607 [OGE])),
#  (Equity(2434 [ED]), Equity(2968 [NEE])),
#  (Equity(2434 [ED]), Equity(5484 [ES])),
#  (Equity(2434 [ED]), Equity(8140 [WEC])),
#  (Equity(2434 [ED]), Equity(21964 [XEL])),
#  (Equity(2434 [ED]), Equity(36098 [AWK])),
#  (Equity(2637 [ETR]), Equity(2968 [NEE])),
#  (Equity(2637 [ETR]), Equity(7011 [SO])),
#  (Equity(2968 [NEE]), Equity(6193 [WTRG])),
#  (Equity(2968 [NEE]), Equity(7011 [SO])),
#  (Equity(5310 [NI]), Equity(5607 [OGE])),
#  (Equity(5310 [NI]), Equity(24783 [AEE])),
#  (Equity(5607 [OGE]), Equity(24783 [AEE])),
#  (Equity(8140 [WEC]), Equity(36098 [AWK])),
#  (Equity(21964 [XEL]), Equity(36098 [AWK])),
#  (Equity(266 [AJG]), Equity(438 [AON])),
#  (Equity(2701 [FNB]), Equity(8011 [VLY])),
#  (Equity(2701 [FNB]), Equity(23718 [PNFP])),
#  (Equity(3066 [FULT]), Equity(8011 [VLY])),
#  (Equity(3066 [FULT]), Equity(23718 [PNFP])),
#  (Equity(3066 [FULT]), Equity(26204 [FHN])),
#  (Equity(3066 [FULT]), Equity(40783 [BKU])),
#  (Equity(8011 [VLY]), Equity(23718 [PNFP])),
#  (Equity(8011 [VLY]), Equity(26204 [FHN])),
#  (Equity(16703 [WTFC]), Equity(18634 [UMPQ])),
#  (Equity(21503 [IBKC]), Equity(21624 [PACW])),
#  (Equity(21503 [IBKC]), Equity(23718 [PNFP])),
#  (Equity(21503 [IBKC]), Equity(26204 [FHN])),
#  (Equity(2855 [FITB]), Equity(17080 [MS])),
#  (Equity(2855 [FITB]), Equity(20088 [GS])),
#  (Equity(2855 [FITB]), Equity(47777 [CFG])),
#  (Equity(4221 [KEY]), Equity(5479 [NTRS])),
#  (Equity(5117 [MTB]), Equity(17080 [MS])),
#  (Equity(5117 [MTB]), Equity(20088 [GS])),
#  (Equity(17080 [MS]), Equity(47777 [CFG])),
#  (Equity(20088 [GS]), Equity(34913 [RF])),
#  (Equity(20088 [GS]), Equity(47777 [CFG])),
#  (Equity(27421 [WAL]), Equity(34913 [RF])),
#  (Equity(913 [BKH]), Equity(4435 [SR])),
#  (Equity(4435 [SR]), Equity(26769 [NWE])),
#  (Equity(21975 [ALE]), Equity(26769 [NWE])),
#  (Equity(2293 [DRE]), Equity(8516 [ELS])),
#  (Equity(2293 [DRE]), Equity(10535 [SUI])),
#  (Equity(2293 [DRE]), Equity(10639 [MAA])),
#  (Equity(2293 [DRE]), Equity(32770 [DEI])),
#  (Equity(2293 [DRE]), Equity(43032 [HTA])),
#  (Equity(3010 [FRT]), Equity(5376 [NNN])),
#  (Equity(3010 [FRT]), Equity(7715 [UDR])),
#  (Equity(3010 [FRT]), Equity(9540 [EQR])),
#  (Equity(3010 [FRT]), Equity(11598 [AIV])),
#  (Equity(3010 [FRT]), Equity(12087 [O])),
#  (Equity(3010 [FRT]), Equity(18834 [AVB])),
#  (Equity(3010 [FRT]), Equity(26553 [ACC])),
#  (Equity(3010 [FRT]), Equity(48103 [STOR])),
#  (Equity(5376 [NNN]), Equity(10027 [REG])),
#  (Equity(5376 [NNN]), Equity(11598 [AIV])),
#  (Equity(7715 [UDR]), Equity(10027 [REG])),
#  (Equity(7715 [UDR]), Equity(11598 [AIV])),
#  (Equity(7715 [UDR]), Equity(12087 [O])),
#  (Equity(7715 [UDR]), Equity(18834 [AVB])),
#  (Equity(7715 [UDR]), Equity(43032 [HTA])),
#  (Equity(8516 [ELS]), Equity(16843 [ARE])),
#  (Equity(8516 [ELS]), Equity(24785 [PLD])),
#  (Equity(8516 [ELS]), Equity(43032 [HTA])),
#  (Equity(9348 [CPT]), Equity(9540 [EQR])),
#  (Equity(9348 [CPT]), Equity(41872 [VER])),
#  (Equity(9348 [CPT]), Equity(48103 [STOR])),
#  (Equity(9540 [EQR]), Equity(41872 [VER])),
#  (Equity(9540 [EQR]), Equity(43032 [HTA])),
#  (Equity(9540 [EQR]), Equity(48103 [STOR])),
#  (Equity(10027 [REG]), Equity(11465 [ESS])),
#  (Equity(10027 [REG]), Equity(11598 [AIV])),
#  (Equity(10027 [REG]), Equity(12087 [O])),
#  (Equity(10027 [REG]), Equity(18834 [AVB])),
#  (Equity(10027 [REG]), Equity(21713 [WPC])),
#  (Equity(10027 [REG]), Equity(26553 [ACC])),
#  (Equity(10027 [REG]), Equity(48103 [STOR])),
#  (Equity(10535 [SUI]), Equity(10639 [MAA])),
#  (Equity(10535 [SUI]), Equity(24785 [PLD])),
#  (Equity(10535 [SUI]), Equity(43032 [HTA])),
#  (Equity(10639 [MAA]), Equity(43032 [HTA])),
#  (Equity(11465 [ESS]), Equity(21713 [WPC])),
#  (Equity(11598 [AIV]), Equity(12087 [O])),
#  (Equity(11598 [AIV]), Equity(43032 [HTA])),
#  (Equity(11598 [AIV]), Equity(48103 [STOR])),
#  (Equity(12087 [O]), Equity(43032 [HTA])),
#  (Equity(16374 [KRC]), Equity(32770 [DEI])),
#  (Equity(16843 [ARE]), Equity(24785 [PLD])),
#  (Equity(16843 [ARE]), Equity(32770 [DEI])),
#  (Equity(17009 [BXP]), Equity(43032 [HTA])),
#  (Equity(18834 [AVB]), Equity(43032 [HTA])),
#  (Equity(18834 [AVB]), Equity(48103 [STOR])),
#  (Equity(24785 [PLD]), Equity(32770 [DEI])),
#  (Equity(24785 [PLD]), Equity(50642 [INVH])),
#  (Equity(24962 [PSA]), Equity(26733 [CUBE])),
#  (Equity(32770 [DEI]), Equity(45197 [AMH])),
#  (Equity(32770 [DEI]), Equity(50642 [INVH])),
#  (Equity(41872 [VER]), Equity(43032 [HTA])),
#  (Equity(43032 [HTA]), Equity(48103 [STOR])),
#  (Equity(2471 [EGP]), Equity(3675 [EQC])),
#  (Equity(2471 [EGP]), Equity(8965 [HR])),
#  (Equity(3675 [EQC]), Equity(8965 [HR])),
#  (Equity(3675 [EQC]), Equity(45559 [ESRT])),
#  (Equity(5303 [NHI]), Equity(45559 [ESRT])),
#  (Equity(6190 [PSB]), Equity(8965 [HR])),
#  (Equity(8965 [HR]), Equity(11085 [ADC])),
#  (Equity(8965 [HR]), Equity(45559 [ESRT])),
#  (Equity(11085 [ADC]), Equity(45559 [ESRT])),
#  (Equity(39161 [TRNO]), Equity(45111 [REXR])),
#  (Equity(4283 [KO]), Equity(5938 [PG])),
#  (Equity(13451 [RWT]), Equity(35081 [CIM])),
#  (Equity(13451 [RWT]), Equity(38759 [ARI])),
#  (Equity(17702 [NLY]), Equity(36243 [AGNC])),
#  (Equity(26728 [SHO]), Equity(41417 [RLJ]))]

# %%
print "We found %d pairs." % len(pairs)
# Out:
# We found 118 pairs.

# %%
print "In those pairs, there are %d unique tickers." % len(np.unique(pairs))
# Out:
# In those pairs, there are 88 unique tickers.

# %%
stocks = np.unique(pairs)
X_df = pd.DataFrame(index=returns.T.index, data=X)
in_pairs_series = clustered_series.loc[stocks]
stocks = list(np.unique(pairs))
X_pairs = X_df.loc[stocks]

X_tsne = TSNE(learning_rate=50, perplexity=3, random_state=1337).fit_transform(X_pairs)

plt.figure(1, facecolor='white')
plt.clf()
plt.axis('off')
for pair in pairs:
    ticker1 = pair[0].symbol
    loc1 = X_pairs.index.get_loc(pair[0])
    x1, y1 = X_tsne[loc1, :]

    ticker2 = pair[0].symbol
    loc2 = X_pairs.index.get_loc(pair[1])
    x2, y2 = X_tsne[loc2, :]
      
    plt.plot([x1, x2], [y1, y2], 'k-', alpha=0.3, c='gray');
        
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], s=220, alpha=0.9, c=[in_pairs_series.values], cmap=cm.Paired)
plt.title('T-SNE Visualization of Validated Pairs');
